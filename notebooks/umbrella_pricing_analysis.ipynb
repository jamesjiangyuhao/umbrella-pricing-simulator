# %% [markdown]
# # Competitive Personal Umbrella Pricing Analysis
#
# This notebook documents a fully synthetic pricing simulation and benchmarking workflow.

# %% [markdown]
# ## Sections
#
# 1. Business problem
# 2. Synthetic data generation
# 3. Pricing logic explanation
# 4. Carrier comparison
# 5. Segment analysis
# 6. Geographic analysis
# 7. Sensitivity analysis
# 8. Benchmarking results
# 9. Insights
# 10. Limitations and assumptions

# %%
import pandas as pd
from src.generate_synthetic_data import generate_profiles
from src.pricing_engine import simulate_all_carriers

profiles = generate_profiles(100000)
pricing = simulate_all_carriers(profiles)
profiles.head(), pricing.head()

# %% [markdown]
# ## Limitations
#
# The data and pricing behavior are fictional. The workflow is intended to demonstrate analytics structure, not to represent real underwriting, actuarial, regulatory, or pricing practice.
